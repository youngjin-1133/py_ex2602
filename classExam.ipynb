# %%
# 클래스 -> 객체를 표현하기 위한 문법의 일종
#프로그래밍으로 객체를 만들 때 사용하는 것

# 전사, 마법사 ,궁수 ,자동차, 비행기 -> object
# -> 현실, 가상, 개념

# 속성 - attribute
# 능력(기능, 동사적) - method

class person:           # 설계도
    def hello(self)
        print("hi")

jin = person() # jin은 person의 인스턴스    # 결과
jin.hello()


a = 10
print(type(a))

b = [1, 2, 3]
print(type(b))

c = {"x" : 1, "y" : 2}?

# %%
# 빈 클래스 만들기
class person: 
    pass

# %%
class person
    def hello(self):
        print("hello")

    def hi(self):
        self. hello()

jin = person()
jin.hi()

# %%
class person():
    def __init__(self):
        self.hello = '안녕하세요' # 인스턴스 속성

    def hi(self):
        print(self.hello)

jin = person() # 이 때 __init__?
jin.hi()

# %%
#!# 클래스 외부에서는 접근 불가, 클래스 내부에서만 사용 가능한 private attrloute
class person()
    def __isit__(selfm name)
