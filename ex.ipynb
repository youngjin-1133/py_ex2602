# %%
print("s를 이루는 문장 중에서 문자 4개 출력, 첫 인덱스 생략")
print("s[:4]")

print("s를 이루는 문장 중에서 앞에 문자 3개를 건너 뛰고 1개 출력 len")
print(s[3:len(s)])

print("s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고 뒤 인덱스 생략")
print(s[3:])

print("s를 이루는 문자를 하나씩 출력, while")
s = "안녕하세요"

print(s)
# Out:
# s를 이루는 문장 중에서 문자 4개 출력, 첫 인덱스 생략
# s[:4]
# s를 이루는 문장 중에서 앞에 문자 3개를 건너 뛰고 1개 출력 len
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 print("s[:4]")
#       4 print("s를 이루는 문장 중에서 앞에 문자 3개를 건너 뛰고 1개 출력 len")
# ----> 5 print(s[3:len(s)])
#       7 print("s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고 뒤 인덱스 생략")
#       8 print(s[3:])
#
# NameError: name 's' is not defined

# %%
print("== 예제 3 ==")
s = "a안b녕c하d세e요f"

print("s를 이루는 문장 중에서 한글만 출력")
print(s[1] + s[3] + s[5] + s[7] + s[9])

print("s를 이루는 문장 중에서 한글만 출력, for, if, or, continue, 방법 1")
for c in s:
    if c == 'a' or c == 'b' or c == 'c' or c == 'd' or c == 'e' c == 'f'
    continue
print(c)

print("s를 이루는")
