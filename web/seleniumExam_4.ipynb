# %%
"""
연습 사이트: https://[Log in to view URL]
"""

from selenium import webdriver
from selenium.webdriver.common.by import By


# -------------------------------------------------
# 공통: 드라이버 실행 및 1페이지 접속
# -------------------------------------------------
driver = webdriver.Chrome()
driver.get("https://[Log in to view URL]")


# =================================================
# 문제 1 (기초)
# =================================================
"""
[문제 1]
1페이지에서 모든 명언(text)과 저자(author)를 출력하세요.

출력 형식:
명언 - 저자

조건:
- find_elements()를 사용하세요.
- 각 quote 블록 안에서 다시 요소를 찾으세요.
"""

print("\n=====[문제1 정답]=====")
quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

for block in quote_blocks:
    quote_text = block.find_element(By.CLASS_NAME, "text").text
    author = block.find_element(By.CLASS_NAME, "author").text
    print(quote_text, "-", author)

# =================================================
# 문제 2 (중급)
# =================================================
"""
[문제 2]
1페이지에서 각 명언의 태그 개수를 함께 출력하세요.

출력 형식 예:
명언 - 저자 (태그 3개)

조건:
- 태그는 class="tag" 입니다.
- 태그는 여러 개일 수 있습니다.
- len()을 활용하세요.
"""

print("\n=====[문제2 정답]=====")
quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

for block in quote_blocks:
    quote_text = block.find_element(By.CLASS_NAME, "text").text
    author = block.find_element(By.CLASS_NAME, "author").text
    tag_elements = block.find_elements(By.CLASS_NAME, "tag")
    print(f"{quote_text} - {author} (태그 {len(tag_elements)}개)")

# =================================================
# 문제 3 (중상)
# =================================================
"""
[문제 3]
2페이지까지 이동하여 총 몇 개의 명언을 수집했는지 출력하세요.

조건:
- Next 버튼을 클릭하세요.
- 반복문을 사용하세요.
- 페이지 이동 후 다시 요소를 수집하세요.
"""

print("\n=====[문제3 정답]=====")
total_quotes = 0
current_page = 1
MAX_PAGES = 2

while current_page <= MAX_PAGES:
    quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")
    total_quotes += len(quote_blocks)

    # 2페이지까지니까, 1페이지에서만 next를 누르면 됨
    if current_page > MAX_PAGES:
        next_buttons = driver.find_elements(By.CSS_SELECTOR, "li.next a")
        if not next_buttons:
            break
        next_buttons[0].click()

    current_page += 1   

print("2페이지까지 총 명언 개수 :", total_quotes)

# =================================================
# 문제 4 (활용)
# =================================================
"""
[문제 4]
3페이지까지 수집하면서, 태그에 "love"가 포함된 명언만 출력하세요.

출력 형식:
[LOVE] 명언 - 저자

조건:
- 태그 목록(tags) 안에 "love"가 있으면 출력합니다.
"""

print("\n=====[문제4 정답]=====")
driver.get("https://quotes.toscrape.com")

current_page = 1
MAX_PAGES = 3

while current_page <= MAX_PAGES:
    quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

    for block in quote_blocks:
        quote_text = block.find_element(By.CLASS_NAME, "text").text
        author = block.find_element(By.CLASS_NAME, "author").text
        tag_elements = block.find_elements(By.CLASS_NAME, "tag")
        tags = [t.text for t in tag_elements]

        if "love" in tags:
            print(f"[LOVE] {quote_text} - {author}")
    
    if current_page < MAX_PAGES:
        next_buttons = driver.find_elements(By.CSS_SELECTOR, "li.next a")
        if not next_buttons:
            break
        next_buttons[0].click()
    
    current_page += 1

# =================================================
# 문제 5 (도전)
# =================================================
"""
[문제 5]
3페이지까지 수집한 뒤, 저자별로 명언이 몇 개 있는지 출력하세요.

출력 예:
Albert Einstein : 2개
Mark Twain : 3개

조건:
- 딕셔너리를 사용하세요.
- key = author, value = 개수
"""

print("\n=====[문제5 정답]=====")
driver.get("https://quotes.toscrape.com")
author_count = {}
current_page = 1
MAX_PAGES = 3

while current_page <= MAX_PAGES:
    quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

    for block in quote_blocks:
        author = block.find_element(By.CLASS_NAME, "author").text

        # 딕셔너리 집계 패턴
        # author가 없으면 0에서 시작해서 1씩 증가
        author_count[author] = author_count.get(author, 0) + 1
    
    if current_page < MAX_PAGES:
        next_buttons = driver.find_elements(By.CSS_SELECTOR, "li.next a")
        if not next_buttons:
            break
        next_buttons[0].click()

    current_page += 1

for author, count in author_count.items():
    print(f"{author} : {count}개")
# -------------------------------------------------
# 브라우저 종료
# -------------------------------------------------
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Cell In[3], line 13
#       9 # -------------------------------------------------
#      10 # 공통: 드라이버 실행 및 1페이지 접속
#      11 # -------------------------------------------------
#      12 driver = webdriver.Chrome()
# ---> 13 driver.get("https://[Log in to view URL]")
#      16 # =================================================
#      17 # 문제 1 (기초)
#      18 # =================================================
#      19 """
#      20 [문제 1]
#      21 1페이지에서 모든 명언(text)과 저자(author)를 출력하세요.
#    (...)     28 - 각 quote 블록 안에서 다시 요소를 찾으세요.
#      29 """
#
# File c:\Users\201\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:466, in WebDriver.get(self, url)
#     453 def get(self, url: str) -> None:
#     454     """Navigate the browser to the specified URL.
#     455
#     456     The method does not return until the page is fully loaded (i.e. the
#    (...)    464         `driver.get("https://example.com")`
#     465     """
# --> 466     self.execute(Command.GET, {"url": url})
#
# File c:\Users\201\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:446, in WebDriver.execute(self, driver_command, params)
#     443 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     445 if response:
# --> 446     self.error_handler.check_response(response)
#     447     response["value"] = self._unwrap_value(response.get("value", None))
#     448     return response
#
# File c:\Users\201\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: invalid argument
#   (Session info: chrome=145.0.7632.117)
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff7ef51aa55
# 	0x7ff7ef278630
# 	0x7ff7ef00d546
# 	0x7ff7eeff9b24
# 	0x7ff7eeff7eff
# 	0x7ff7eeff8452
# 	0x7ff7ef011a06
# 	0x7ff7ef0b6734
# 	0x7ff7ef0919da
# 	0x7ff7ef0b591c
# 	0x7ff7ef059098
# 	0x7ff7ef059f83
# 	0x7ff7ef547810
# 	0x7ff7ef541afd
# 	0x7ff7ef562c1a
# 	0x7ff7ef293345
# 	0x7ff7ef29b81c
# 	0x7ff7ef281924
# 	0x7ff7ef281ad6
# 	0x7ff7ef267e47
# 	0x7ffad9ea7374
# 	0x7ffadb93cc91
